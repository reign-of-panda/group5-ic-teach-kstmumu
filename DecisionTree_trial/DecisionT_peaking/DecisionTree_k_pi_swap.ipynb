# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix

import pickle, time

# pd.set_option("display.max_columns", 100)

# %%
df = pd.read_pickle("../../data/total_dataset.pkl") # total dataset
#df = df.drop(["accept_kaon", "accept_muon", "accept_pion", "dilepton_mass"], axis = 1) # signal and background should have the same columns
print("Total dataset number of events: ", len(df))

signal = pd.read_csv("../../data/csv/sig.csv") # as a signal, simulated data is used
print("Number of simulated signal events: ", len(signal))

bg = pd.read_pickle("../../data/k_pi_swap.pkl")
print("Number of background events: ", len(bg))

# labels for decision trees (0 - background; 1 - signal)
vals = np.concatenate([np.zeros(len(bg)), np.ones(len(signal))])
print("Length of labels array", len(vals))

# (X - independent; Y - dependent) variables for the decision tree classifier
X = bg.append(signal) # concatenation of the two dataframes
X = X.drop(["year", "polarity", "Unnamed: 0"], axis = 1) # dropping columns that have not effect, but may have NaN or other inappropriate data
Y = vals
# Out:
# Total dataset number of events:  498357
# Number of simulated signal events:  8802
# Number of background events:  22106
# Length of labels array 30908

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y) # splitting data into test and train samples
clf_dt = DecisionTreeClassifier() # creating a Decision Tree
clf_dt = clf_dt.fit(X_train, Y_train) # training it

# Plotting a resulting decision tree
plt.figure(figsize = (15, 7.5))
plot_tree(clf_dt,
         filled = True,
         rounded = True,
         class_names = ["Bg", "Sig"],
         feature_names = X.columns)

# Plotting a confusion matrix, which will check on the test data false-positive and false-negative identifications
plot_confusion_matrix(clf_dt, X_test, Y_test, display_labels = ["Background", "Signal"])

# %% [markdown]
# <h3>Next section investigates overfitting prevention</h3>

# %% [markdown]
# <h3>End of investigation</h3>

# %%
path = clf_dt.cost_complexity_pruning_path(X_train, Y_train)
ccp_alphas = path.ccp_alphas
ccp_alphas = ccp_alphas[:-1] # last one should be removed

print(ccp_alphas)
print(len(ccp_alphas))
# Out:
# [0.00000000e+00 4.24076117e-05 4.24647340e-05 4.27030322e-05
#  4.28472992e-05 4.28964248e-05 4.29049629e-05 4.29093159e-05
#  4.29209048e-05 4.29395221e-05 4.29772090e-05 4.29935290e-05
#  4.31354455e-05 4.35579084e-05 4.93081225e-05 5.12827336e-05
#  5.16871106e-05 5.38091348e-05 5.74967668e-05 5.75183699e-05
#  5.75183699e-05 5.75183699e-05 6.47081662e-05 6.47081662e-05
#  6.72527991e-05 6.90220439e-05 6.90220439e-05 6.90220439e-05
#  6.90220439e-05 6.90220439e-05 7.18979624e-05 7.18979624e-05
#  7.54928605e-05 7.54928605e-05 7.76497994e-05 7.96408199e-05
#  7.98590521e-05 8.01148724e-05 8.07112610e-05 8.11009016e-05
#  8.19636771e-05 8.19880493e-05 8.22646454e-05 8.26826568e-05
#  8.31427805e-05 8.36979432e-05 8.37585022e-05 8.40653099e-05
#  8.43387334e-05 8.45879741e-05 8.48342702e-05 8.48941928e-05
#  8.61978798e-05 8.84897999e-05 1.00657147e-04 1.02007195e-04
#  1.16271860e-04 1.22705856e-04 1.29416332e-04 1.33840822e-04
#  1.37182312e-04 1.38044088e-04 1.38044088e-04 1.43795925e-04
#  1.44097303e-04 1.46284700e-04 1.47904380e-04 1.49904465e-04
#  1.53593010e-04 1.56121290e-04 1.60693853e-04 1.61051436e-04
#  1.61770415e-04 1.62097224e-04 1.63404460e-04 1.65877955e-04
#  1.70864719e-04 1.79744906e-04 1.81594801e-04 1.91912254e-04
#  1.96329369e-04 1.99539889e-04 2.01314295e-04 2.04809430e-04
#  2.09981962e-04 2.47580973e-04 2.87591850e-04 2.98687523e-04
#  3.04187883e-04 3.34538064e-04 3.48563447e-04 3.78521236e-04
#  4.14470607e-04 4.68220860e-04 4.77735774e-04 4.98038112e-04
#  6.51988696e-04 7.72141832e-04 8.44950086e-04 8.89144625e-04
#  9.97500484e-04 1.01911914e-03 1.07713485e-03 1.55474652e-03
#  2.17321748e-03 2.58241565e-03 3.34001626e-03 4.93884185e-03
#  1.90643744e-02 2.35422595e-02]
# 110

# %%
alpha_loop_values = []
# Check different alpha values with cross validation providing errorbars
init_time = time.time()
for num, ccp_alpha in enumerate(ccp_alphas): # not all alphas are used to save some time - for better precision all ccp_alphas should be looked at
    print("Starting alpha num: ", num)
    start_time = time.time()
    clf_dt = DecisionTreeClassifier(ccp_alpha = ccp_alpha)
    scores = cross_val_score(clf_dt, X_train, Y_train, cv = 5)
    alpha_loop_values.append([ccp_alpha, np.mean(scores), np.std(scores)])
    print("Execution time for alpha: ", time.time() - start_time)
print("Total execution time: ", time.time() - init_time)
    
alpha_results = pd.DataFrame(alpha_loop_values, columns = ["alpha", "mean_accuracy", "std"])

alpha_results.plot(x = 'alpha', y = 'mean_accuracy', yerr = 'std', marker = 'o')
# Out:
# Starting alpha num:  0
# Execution time for alpha:  13.831429958343506
# Starting alpha num:  1
# Execution time for alpha:  13.27819037437439
# Starting alpha num:  2
# Execution time for alpha:  13.268030643463135
# Starting alpha num:  3
# Execution time for alpha:  13.266698837280273
# Starting alpha num:  4
# Execution time for alpha:  12.953496217727661
# Starting alpha num:  5
# Execution time for alpha:  12.935126781463623
# Starting alpha num:  6
# Execution time for alpha:  13.265631914138794
# Starting alpha num:  7
# Execution time for alpha:  12.779227018356323
# Starting alpha num:  8
# Execution time for alpha:  12.920879602432251
# Starting alpha num:  9
# Execution time for alpha:  13.093786239624023
# Starting alpha num:  10
# Execution time for alpha:  13.04689645767212
# Starting alpha num:  11
# Execution time for alpha:  12.982298851013184
# Starting alpha num:  12
# Execution time for alpha:  12.874086856842041
# Starting alpha num:  13
# Execution time for alpha:  12.780191421508789
# Starting alpha num:  14
# Execution time for alpha:  13.06041693687439
# Starting alpha num:  15
# Execution time for alpha:  13.393915891647339
# Starting alpha num:  16
# Execution time for alpha:  13.20928144454956
# Starting alpha num:  17
# Execution time for alpha:  13.162559270858765
# Starting alpha num:  18
# Execution time for alpha:  12.828161001205444
# Starting alpha num:  19
# Execution time for alpha:  13.73435354232788
# Starting alpha num:  20
# Execution time for alpha:  12.968790769577026
# Starting alpha num:  21
# Execution time for alpha:  12.95108413696289
# Starting alpha num:  22
# Execution time for alpha:  12.921902418136597
# Starting alpha num:  23
# Execution time for alpha:  12.878734350204468
# Starting alpha num:  24
# Execution time for alpha:  13.073410987854004
# Starting alpha num:  25
# Execution time for alpha:  13.10730767250061
# Starting alpha num:  26
# Execution time for alpha:  13.09380292892456
# Starting alpha num:  27
# Execution time for alpha:  12.98443341255188
# Starting alpha num:  28
# Execution time for alpha:  13.266693115234375
# Starting alpha num:  29
# Execution time for alpha:  13.164901733398438
# Starting alpha num:  30
# Execution time for alpha:  13.396611213684082
# Starting alpha num:  31
# Execution time for alpha:  12.966695308685303
# Starting alpha num:  32
# Execution time for alpha:  12.968811988830566
# Starting alpha num:  33
# Execution time for alpha:  13.044772148132324
# Starting alpha num:  34
# Execution time for alpha:  12.891894340515137
# Starting alpha num:  35
# Execution time for alpha:  12.746739149093628
# Starting alpha num:  36
# Execution time for alpha:  12.905227899551392
# Starting alpha num:  37
# Execution time for alpha:  12.872953176498413
# Starting alpha num:  38
# Execution time for alpha:  13.078146934509277
# Starting alpha num:  39
# Execution time for alpha:  12.8886079788208
# Starting alpha num:  40
# Execution time for alpha:  12.576030015945435
# Starting alpha num:  41
# Execution time for alpha:  12.928230285644531
# Starting alpha num:  42
# Execution time for alpha:  12.881275177001953
# Starting alpha num:  43
# Execution time for alpha:  13.1562659740448
# Starting alpha num:  44
# Execution time for alpha:  12.92177414894104
# Starting alpha num:  45
# Execution time for alpha:  12.590764045715332
# Starting alpha num:  46
# Execution time for alpha:  12.841720342636108
# Starting alpha num:  47
# Execution time for alpha:  13.125047445297241
# Starting alpha num:  48
# Execution time for alpha:  12.982290983200073
# Starting alpha num:  49
# Execution time for alpha:  12.953198671340942
# Starting alpha num:  50
# Execution time for alpha:  12.826044082641602
# Starting alpha num:  51
# Execution time for alpha:  13.093807697296143
# Starting alpha num:  52
# Execution time for alpha:  13.108325719833374
# Starting alpha num:  53
# Execution time for alpha:  14.300983190536499
# Starting alpha num:  54
# Execution time for alpha:  13.2959623336792
# Starting alpha num:  55
# Execution time for alpha:  12.953185081481934
# Starting alpha num:  56
# Execution time for alpha:  12.669795513153076
# Starting alpha num:  57
# Execution time for alpha:  12.920902013778687
# Starting alpha num:  58
# Execution time for alpha:  13.046911716461182
# Starting alpha num:  59
# Execution time for alpha:  13.02920126914978
# Starting alpha num:  60
# Execution time for alpha:  12.93754243850708
# Starting alpha num:  61
# Execution time for alpha:  12.747922420501709
# Starting alpha num:  62
# Execution time for alpha:  12.982293128967285
# Starting alpha num:  63
# Execution time for alpha:  12.890737533569336
# Starting alpha num:  64
# Execution time for alpha:  12.91976284980774
# Starting alpha num:  65
# Execution time for alpha:  13.004745721817017
# Starting alpha num:  66
# Execution time for alpha:  12.749370098114014
# Starting alpha num:  67
# Execution time for alpha:  13.024112939834595
# Starting alpha num:  68
# Execution time for alpha:  13.342717170715332
# Starting alpha num:  69
# Execution time for alpha:  13.09486198425293
# Starting alpha num:  70
# Execution time for alpha:  13.202070951461792
# Starting alpha num:  71
# Execution time for alpha:  13.019087314605713
# Starting alpha num:  72
# Execution time for alpha:  12.664317607879639
# Starting alpha num:  73
# Execution time for alpha:  13.767762899398804
# Starting alpha num:  74
# Execution time for alpha:  13.234529972076416
# Starting alpha num:  75
# Execution time for alpha:  13.03119158744812
# Starting alpha num:  76
# Execution time for alpha:  13.40625262260437
# Starting alpha num:  77
# Execution time for alpha:  12.779232263565063
# Starting alpha num:  78
# Execution time for alpha:  12.890651941299438
# Starting alpha num:  79
# Execution time for alpha:  13.060441255569458
# Starting alpha num:  80
# Execution time for alpha:  13.14065170288086
# Starting alpha num:  81
# Execution time for alpha:  12.984431743621826
# Starting alpha num:  82
# Execution time for alpha:  12.935423374176025
# Starting alpha num:  83
# Execution time for alpha:  12.670857191085815
# Starting alpha num:  84
# Execution time for alpha:  13.078234910964966
# Starting alpha num:  85
# Execution time for alpha:  13.04473090171814
# Starting alpha num:  86
# Execution time for alpha:  13.26363468170166
# Starting alpha num:  87
# Execution time for alpha:  12.987473964691162
# Starting alpha num:  88
# Execution time for alpha:  12.79273796081543
# Starting alpha num:  89
# Execution time for alpha:  13.07321047782898
# Starting alpha num:  90
# Execution time for alpha:  12.98829460144043
# Starting alpha num:  91
# Execution time for alpha:  13.218820810317993
# Starting alpha num:  92
# Execution time for alpha:  12.989696979522705
# Starting alpha num:  93
# Execution time for alpha:  12.805176496505737
# Starting alpha num:  94
# Execution time for alpha:  12.795855045318604
# Starting alpha num:  95
# Execution time for alpha:  13.02916932106018
# Starting alpha num:  96
# Execution time for alpha:  12.890672445297241
# Starting alpha num:  97
# Execution time for alpha:  12.982339859008789
# Starting alpha num:  98
# Execution time for alpha:  12.906322479248047
# Starting alpha num:  99
# Execution time for alpha:  13.908304929733276
# Starting alpha num:  100
# Execution time for alpha:  13.097444295883179
# Starting alpha num:  101
# Execution time for alpha:  12.927788734436035
# Starting alpha num:  102
# Execution time for alpha:  12.938450813293457
# Starting alpha num:  103
# Execution time for alpha:  13.0937979221344
# Starting alpha num:  104
# Execution time for alpha:  12.826032638549805
# Starting alpha num:  105
# Execution time for alpha:  13.941749095916748
# Starting alpha num:  106
# Execution time for alpha:  12.997931480407715
# Starting alpha num:  107
# Execution time for alpha:  13.359384775161743
# Starting alpha num:  108
# Execution time for alpha:  12.937558889389038
# Starting alpha num:  109
# Execution time for alpha:  12.920826196670532
# Total execution time:  1435.3654141426086
# <AxesSubplot:xlabel='alpha'>

# %%
# find the best alpha in terms of absolute accuracy and its error
alpha_results[82:-18].plot(x = 'alpha', y = 'mean_accuracy', yerr = 'std', marker = 'o')
# Out:
# <AxesSubplot:xlabel='alpha'>

# %%
# Extract the best value of alpha
ideal_alpha = ccp_alphas[(ccp_alphas > 0.0003) & (ccp_alphas < 0.000325)][0]
ideal_alpha = float(ideal_alpha)
print(ideal_alpha)

# Resulting decision tree with the ccp_alpha being used to prevent overfitting
clf_dt = DecisionTreeClassifier(ccp_alpha = ideal_alpha)
clf_dt = clf_dt.fit(X_train, Y_train)

plt.figure(figsize = (60, 30))
plot_tree(clf_dt,
         filled = True,
         rounded = True,
         class_names = ["Bg", "Sig"],
         feature_names = X.columns)

# Corresponding confusion matrix
plot_confusion_matrix(clf_dt, X_test, Y_test, display_labels = ["Background", "Signal"])
# Out:
# 0.0003041878827636784

# %%
with open("tree_k_pi_swap", 'wb') as f: # exporting decision tree to 'tree_jpsi' binary file
    pickle.dump(clf_dt, f)

# %%
df = pd.read_pickle("../../data/total_dataset.pkl")
#df = df.drop(["accept_kaon", "accept_muon", "accept_pion", "dilepton_mass"], axis = 1)
#print("Total number of events:", len(df))
#total_data = df[(df["B0_MM"] > min_mass) & (df["B0_MM"] < max_mass)].drop(["year", "polarity", "Unnamed: 0"], axis = 1)
#print("Number of events in the mass region", len(total_data))

# Passing data to decision tree
result = clf_dt.predict(df.drop(["year", "polarity"], axis = 1))

print("Number of bg (0) and signal (1) events identified", np.unique(result, return_counts = True))
plt.title("Background vs Signal identification")
plt.hist(result)
plt.show()

# Extracting signal data to 'Filtered_data.pkl'
df["Result"] = result
filtered = df[df["Result"] == 1]
filtered.to_pickle("Filtered_data.pkl")

# Histogram of the filtered data
plt.hist(df['B0_MM'], range=[5170, 5600], bins=300, zorder=1, label = "unfiltered")
plt.hist(filtered['B0_MM'], range=[5170, 5600], bins=300, zorder=2, label = "filtered")
plt.legend()
plt.show()
# Out:
# Number of bg (0) and signal (1) events identified (array([0., 1.]), array([209678, 288679], dtype=int64))
